# %% [markdown]
# ![Image](https://upload.wikimedia.org/wikipedia/commons/d/da/Franklin_Hall_2.jpg)

# %% [markdown]
# # Systems Check
# ### Tyler Hilbert
# ##### EMAT 62110 - Interactive Data
#
# Below is a list of what I hope to get out of this course
# 1. **Learn Python** - I'm excited to learn a new coding language - I enjoyed learning JavaScript, but hope that Python is fun.
# 2. *Write better data reports* - I do not have formal training in doing data reporting, so this provides me with an opportunity to receive that training.
# 3. Become a better storyteller with data - I currently just give the data to people with little detail/description. I'd like to learn how to better convey what points need attention and why they are important.

# %%
my_name = "Tyler"
my_name
# Out:
# 'Tyler'

# %%
def give_name():
    print(my_name)

give_name()
# Out:
# Tyler

# %%
def return_name():
    return my_name
new_name = return_name()

# %%
new_name
# Out:
# 'Tyler'
